# %% [markdown]
# <a href="https://colab.research.google.com/github/Rexhark/Deep-Learning/blob/main/Neural_Network_Sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget "https://archive.org/download/ages-and-heights/AgesAndHeights.pkl"
# Out:
# --2023-09-18 01:22:18--  https://archive.org/download/ages-and-heights/AgesAndHeights.pkl
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia601802.us.archive.org/31/items/ages-and-heights/AgesAndHeights.pkl [following]
# --2023-09-18 01:22:19--  https://ia601802.us.archive.org/31/items/ages-and-heights/AgesAndHeights.pkl
# Resolving ia601802.us.archive.org (ia601802.us.archive.org)... 207.241.227.72
# Connecting to ia601802.us.archive.org (ia601802.us.archive.org)|207.241.227.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2406 (2.3K) [application/octet-stream]
# Saving to: ‘AgesAndHeights.pkl.1’
#
# AgesAndHeights.pkl. 100%[===================>]   2.35K  --.-KB/s    in 0s
#
# 2023-09-18 01:22:19 (1.33 GB/s) - ‘AgesAndHeights.pkl.1’ saved [2406/2406]

# %%
data = pd.read_pickle('AgesAndHeights.pkl')
data
# Out:
#           Age     Height
# 0   14.767874  59.627484
# 1    3.107671  36.146453
# 2    7.266917  46.912878
# 3    1.815180  29.125660
# 4   16.753758  68.170414
# ..        ...        ...
# 95   7.323712  46.857505
# 96   5.591509  39.339990
# 97   2.625606  32.918925
# 98   5.519293  40.704154
# 99  13.117413  55.177407
#
# [100 rows x 2 columns]

# %%
umur = data['Age']
tinggi = data['Height']
plt.scatter(umur, tinggi)
plt.title('Tinggi vs Umur')
plt.xlabel('Umur (tahun)')
plt.ylabel('Tinggi (inci)')
# Out:
# Text(0, 0.5, 'Tinggi (inci)')

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(8, input_shape=(1,), activation='relu'))
model.add(tf.keras.layers.Dense(1))
model.compile(loss='mse')

# %%
model.fit(x=umur, y=tinggi, epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2229.9573
# Epoch 2/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2196.8354
# Epoch 3/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2173.5088
# Epoch 4/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2154.8010
# Epoch 5/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2137.5498
# Epoch 6/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2122.1443
# Epoch 7/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2106.8267
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2090.9995
# Epoch 9/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2076.9827
# Epoch 10/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2062.7959
# Epoch 11/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2049.3325
# Epoch 12/1000
# ...

# %%
plt.scatter(umur, tinggi)
plt.title('Tinggi vs Umur')
x = list(range(30))
preds  = model.predict(x)
plt.plot(x, preds, color='green')
plt.xlabel('Umur (tahun)')
plt.ylabel('Tinggi (inci)')
# Out:
# 1/1 [==============================] - 0s 72ms/step
# Text(0, 0.5, 'Tinggi (inci)')
